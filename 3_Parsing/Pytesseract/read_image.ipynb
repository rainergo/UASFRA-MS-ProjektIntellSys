# %%
import pytesseract as pytess
import platform

system = platform.system()
if system == 'Windows':
    pytess.pytesseract.tesseract_cmd = r'C:\\Program Files\\Tesseract-OCR\\tesseract.exe'
elif system == 'Linux':
    pytess.pytesseract.tesseract_cmd = r'usr/bin/tesseract'


from config import *
path = allianz_jpg

# %%
txt_from_img = pytess.image_to_string(path, lang='eng')
print(txt_from_img)
# Out:
# Allianz @
#
# Sustainability Report 2020
#
# 05.6 Metrics and targets
#
# Regional corporate bonds portfolio indicators
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# o1
# Inne ey) ee | Ne) eT
# ez Europe Region AuM €bn 90.92 12% 89.87
# Sustainability strategy ‘Absolute emissions mntcOxe 977 79% 1060
# ‘ond .governancs: Relative emissions 1CO,e/€ mn invested 4600 13.1% 5293
# oa Weighted average carbon intensity £CO,e/€ mn sales 7528 05% 7563
# Sustainability in our core ‘North America Region AuM €bn, 7444 23% 72:80
# business activities ‘Absolute emissions matcOne 758 55% 739
# 04 Relative emissions 1 CO,e/€ mn invested 3572 05% 35.89
# Sustainability Imour organization: Weighted average carbon intensity tCO,e/€ mn sales 118.14 34% 11427
# a Asia/Pacific Region AuM €bn 652 20% 665
# Allianz’s climate-related ‘Absolute emissions mnt CO;e 035 346% 053
# ansatasexstit Relative emissions 1 CO,e/€ mn invested 164 383% 266
# ...

# %%
data_from_img = pytess.image_to_data(path, lang='eng')
print(data_from_img)
# Out:
# level	page_num	block_num	par_num	line_num	word_num	left	top	width	height	conf	text
# 1	1	0	0	0	0	0	0	1683	1190	-1
# 2	1	1	0	0	0	75	169	131	33	-1
# 3	1	1	1	0	0	75	169	131	33	-1
# 4	1	1	1	1	0	75	169	131	33	-1
# 5	1	1	1	1	1	75	173	91	22	90	Allianz
# 5	1	1	1	1	2	173	169	33	33	85	@
# 2	1	2	0	0	0	299	181	169	12	-1
# 3	1	2	1	0	0	299	181	169	12	-1
# 4	1	2	1	1	0	299	181	169	12	-1
# 5	1	2	1	1	1	299	181	86	12	93	Sustainability
# 5	1	2	1	1	2	390	181	43	12	96	Report
# 5	1	2	1	1	3	438	181	30	10	91	2020
# 2	1	3	0	0	0	299	223	275	23	-1
# 3	1	3	1	0	0	299	223	275	23	-1
# 4	1	3	1	1	0	299	223	275	23	-1
# 5	1	3	1	1	1	299	223	46	18	96	05.6
# 5	1	3	1	1	2	355	223	80	18	96	Metrics
# 5	1	3	1	1	3	443	223	42	18	96	and
# 5	1	3	1	1	4	493	225	81	21	96	targets
# 2	1	4	0	0	0	299	296	369	17	-1
# 3	1	4	1	0	0	299	296	369	17	-1
# 4	1	4	1	1	0	299	296	369	17	-1
# 5	1	4	1	1	1	299	296	73	17	96	Regional
# 5	1	4	1	1	2	376	298	79	15	96	corporate
# 5	1	4	1	1	3	460	296	49	14	96	bonds
# 5	1	4	1	1	4	514	296	70	17	94	portfolio
# ...

# %%
box_from_img = pytess.image_to_boxes(path, lang='eng')
print(box_from_img)
# Out:
# A 75 995 94 1017 0
# l 81 995 102 1017 0
# l 94 995 101 1017 0
# i 102 995 118 1017 0
# a 120 995 135 1012 0
# n 136 995 152 1012 0
# z 153 995 166 1012 0
# @ 173 988 206 1021 0
# S 299 997 305 1009 0
# u 299 999 306 1009 0
# s 307 999 313 1006 0
# t 315 999 325 1008 0
# a 318 997 333 1009 0
# i 326 999 337 1006 0
# n 334 997 344 1009 0
# a 338 999 345 1006 0
# b 346 999 353 1006 0
# i 355 999 362 1009 0
# l 364 999 365 1006 0
# i 367 999 370 1009 0
# t 371 999 373 1009 0
# y 374 997 385 1008 0
# R 390 999 398 1009 0
# e 399 999 406 1006 0
# p 407 997 414 1006 0
# o 411 997 421 1009 0
# r 415 999 423 1006 0
# t 424 999 433 1008 0
# 2 438 999 444 1009 0
# 0 445 999 452 1009 0
# 2 453 999 460 1009 0
# 0 461 999 468 1009 0
# 0 299 949 311 967 0
# 5 302 949 324 967 0
# . 314 949 331 966 0
# 6 333 949 345 966 0
# M 355 949 370 967 0
# e 355 949 373 967 0
# t 377 949 388 962 0
# r 390 949 397 965 0
# i 400 949 412 967 0
# c 414 949 425 962 0
# s 426 949 435 962 0
# a 443 949 456 962 0
# ...
