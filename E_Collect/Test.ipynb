# %%
from Collect import *

l1 = [{'page_number': 23,
  'Scope 1': {'short_text_and_number': {'292,000 t CO2 emissions   (Scope 1 and 2)'},
   'text_for_word2vec': set(),
   'table_values': set()},
  'Scope 1 and 2': {'short_text_and_number': {'292,000 t CO2 emissions   (Scope 1 and 2)'},
   'text_for_word2vec': set(),
   'table_values': set()}},
 {'page_number': 27,
  'Scope 1': {'short_text_and_number': set(),
   'text_for_word2vec': {'Scope 1 and 2 emissions  1000 metric tons of CO2 equivalent'},
   'table_values': {'221', 'FY 2020', 'Scope 1', 'Scope 1 and 2 emissions'}},
  'Scope 1 and 2': {'short_text_and_number': set(),
   'text_for_word2vec': {'Scope 1 and 2 emissions  1000 metric tons of CO2 equivalent'},
   'table_values': {'FY 2020', 'Scope 1 and 2 emissions'}}},
 {'page_number': 28,
  'Scope 1': {'short_text_and_number': set(),
   'text_for_word2vec': set(),
   'table_values': set()}},
 {'page_number': 76,
  'Scope 1': {'short_text_and_number': set(),
   'text_for_word2vec': {' The  total scope 1 and 2 emissions amounted to  292,000 metric tons of CO2 equivalents',
    'In fiscal year 2020 we achieved to reduce our  scope 1 and 2 emissions by around one third or  148,000 metric tons of CO2 equivalents'},
   'table_values': set()},
  'Scope 1 and 2': {'short_text_and_number': set(),
   'text_for_word2vec': {' The  total scope 1 and 2 emissions amounted to  292,000 metric tons of CO2 equivalents',
    'In fiscal year 2020 we achieved to reduce our  scope 1 and 2 emissions by around one third or  148,000 metric tons of CO2 equivalents'},
   'table_values': set()}}]

l2 = [{'page_number': 22,
       'Scope 1': {'short_text_and_number': set(),
                   'text_for_word2vec': {
                       '•  Develop operative implementation plan to reach minus  25 percent CO2 emissions (scope 1 & 2 of investee  companies according to GHG Protocol) absolute reduction  on public equity and listed corporate debt by 2025 from  a\xa02019 baseline'},
                   'table_values': set()}},
      {'page_number': 41,
       'Scope 1': {'short_text_and_number': set(),
                   'text_for_word2vec': {
                       'Oil & Gas: •  Supporting the commitment set out by the Oil and Gas Climate  Initiative (OGCI) to limit the upstream intensity for Scope 1 and  2 emissions of O&G companies to less than 20 kg CO2e/barrel  and aligning our O&G exposure on average listed equity and  corporate bonds portfolio level to this intensity level'},
                   'table_values': set()},
       'Scope 1 and 2': {'short_text_and_number': set(),
                         'text_for_word2vec': {
                             'Oil & Gas: •  Supporting the commitment set out by the Oil and Gas Climate  Initiative (OGCI) to limit the upstream intensity for Scope 1 and  2 emissions of O&G companies to less than 20 kg CO2e/barrel  and aligning our O&G exposure on average listed equity and  corporate bonds portfolio level to this intensity level'},
                         'table_values': set()}},
      {'page_number': 73,
       'Scope 1': {'short_text_and_number': set(),
                   'text_for_word2vec': set(),
                   'table_values': set()}},
      {'page_number': 92,
       'Scope 1': {'short_text_and_number': set(),
                   'text_for_word2vec': {
                       ' Carbon prices projected for 2030  range from € 45 to 115 per tonne CO2e in 2°C-aligned scenarios,  and increase to € 95 to 374 per tonne CO2e in 1'},
                   'table_values': set()},
       'Scope 1 and 2': {'short_text_and_number': set(),
                         'text_for_word2vec': {
                             ' Carbon prices projected for 2030  range from € 45 to 115 per tonne CO2e in 2°C-aligned scenarios,  and increase to € 95 to 374 per tonne CO2e in 1'},
                         'table_values': set()}},
      {'page_number': 93,
       'Scope 1': {'short_text_and_number': set(),
                   'text_for_word2vec': set(),
                   'table_values': set()},
       'Scope 1 and 2': {'short_text_and_number': set(),
                         'text_for_word2vec': set(),
                         'table_values': set()}},
      {'page_number': 99,
       'Scope 1': {'short_text_and_number': set(),
                   'text_for_word2vec': {
                       '85 % per year (IRENA2 global pathway) •  Scope 1&2 <20kg CO2e / barrel •  50% of AuM to set net-zero 2050 targets for Scope 1+2 emissions •  Engagement with Top 30 (non-aligned) emitters in\xa0portfolio •  Full participation in all available AOA organized sector and asset manager engagements •  Blended finance: 4-5 new vehicles •  Climate-positive solutions: Start investing into e'},
                   'table_values': set()},
       'Scope 1 and 2': {'short_text_and_number': set(),
                         'text_for_word2vec': {
                             '85 % per year (IRENA2 global pathway) •  Scope 1&2 <20kg CO2e / barrel •  50% of AuM to set net-zero 2050 targets for Scope 1+2 emissions •  Engagement with Top 30 (non-aligned) emitters in\xa0portfolio •  Full participation in all available AOA organized sector and asset manager engagements •  Blended finance: 4-5 new vehicles •  Climate-positive solutions: Start investing into e'},
                         'table_values': set()}},
      {'page_number': 107,
       'Scope 1': {'short_text_and_number': {'t CO?e t CO?e t CO?e t CO?e t CO?e'},
                   'text_for_word2vec': {
                       '€ bn mn t CO?e t CO?e/€ mn invested t CO?e/€ mn sales € bn mn t CO?e t CO?e/€ mn invested t CO?e/€ mn sales € bn mn t CO?e t CO?e/€ mn invested t CO?e/€ mn sales € bn mn t CO?e t CO?e/€ mn invested t CO?e/€ mn sales'},
                   'table_values': {'28,714'}}},
      {'page_number': 118,
       'Scope 1': {'short_text_and_number': set(),
                   'text_for_word2vec': {
                       '), report in metric tonnes of carbon dioxide equivalent (tCO2e)  GHG Protocol Scope 1 and Scope 2 emissions'},
                   'table_values': set()}},
      {'page_number': 124,
       'Scope 1': {'short_text_and_number': {'t CO? t CO? t CO? t CO? t CO? t/empl %'},
                   'text_for_word2vec': set(),
                   'table_values': {'203,352', '28,714', '334,033', '42,011'}}}]

keyword_dict_of_lists = {'Scope 1': ['Scope 1', 'scope 1'], 'Scope 1 and 2': ['Scope 1 and 2', 'scope 1 and 2']}



table_keywords = ['2020', 'FY20']


short_text = get_values_and_page_numbers(search_result_list=l1, keyword_dict_of_lists=keyword_dict_of_lists,
                                table_keywords=table_keywords, search_result_dict_key_name='short_text_and_number')

short_text

# %%
table_vals = get_values_and_page_numbers(search_result_list=l1, keyword_dict_of_lists=keyword_dict_of_lists,
                                table_keywords=table_keywords, search_result_dict_key_name='table_values')

table_vals
